# %% [markdown]
# # Analisis conservacion de momentos y energias de dos particulas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
particula1 = pd.read_csv('../data/Tue Oct 20 20:16:50 2020/Particula1.dat')
particula2 = pd.read_csv('../data/Tue Oct 20 20:16:50 2020/Particula2.dat')

# %%
px_total = particula1['px'] + particula2['px']
py_total = particula1['py'] + particula2['py']

# %%
plt.figure(figsize=(14,10))
plt.plot(particula1['px'])

# %%
px_total[1]
# Out:
# 400.0
